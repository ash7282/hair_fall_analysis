# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('D:\\PYTHON CODING\\DATASETS FOR PRACTICE\\HAIR FALL PREDICTION\\Predict Hair Fall.csv')

# %%
df=data.copy()

# %%
df.head()
# Out:
#        Id Genetics Hormonal Changes Medical Conditions  \
# 0  133992      Yes               No            No Data
# 1  148393       No               No             Eczema
# 2  155074       No               No         Dermatosis
# 3  118261      Yes              Yes           Ringworm
# 4  111915       No               No          Psoriasis
#
#   Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                  No Data      Magnesium deficiency  Moderate   19
# 1              Antibiotics      Magnesium deficiency      High   43
# 2         Antifungal Cream        Protein deficiency  Moderate   26
# 3              Antibiotics        Biotin Deficiency   Moderate   46
# 4                 Accutane           Iron deficiency  Moderate   30
#
#   Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   Hair Loss
# 0                    Yes                   Yes      No           No          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         999 non-null    int64
#  1   Genetics                   999 non-null    object
#  2   Hormonal Changes           999 non-null    object
#  3   Medical Conditions         999 non-null    object
#  4   Medications & Treatments   999 non-null    object
#  5   Nutritional Deficiencies   999 non-null    object
#  6   Stress                     999 non-null    object
#  7   Age                        999 non-null    int64
#  8   Poor Hair Care Habits      999 non-null    object
#  9   Environmental Factors      999 non-null    object
#  10  Smoking                    999 non-null    object
#  11  Weight Loss                999 non-null    object
#  12  Hair Loss                  999 non-null    int64
# dtypes: int64(3), object(10)
# ...

# %%
df.describe()
# Out:
#                   Id         Age   Hair Loss
# count     999.000000  999.000000  999.000000
# mean   153354.673674   34.188188    0.497497
# std     25516.041985    9.377980    0.500244
# min    110003.000000   18.000000    0.000000
# 25%    131867.500000   26.000000    0.000000
# 50%    152951.000000   34.000000    0.000000
# 75%    174969.000000   42.000000    1.000000
# max    199949.000000   50.000000    1.000000

# %%
df.isnull().sum()
# Out:
# Id                           0
# Genetics                     0
# Hormonal Changes             0
# Medical Conditions           0
# Medications & Treatments     0
# Nutritional Deficiencies     0
# Stress                       0
# Age                          0
# Poor Hair Care Habits        0
# Environmental Factors        0
# Smoking                      0
# Weight Loss                  0
# Hair Loss                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Genetics', 'Hormonal Changes', 'Medical Conditions',
#        'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress',
#        'Age', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking',
#        'Weight Loss ', 'Hair Loss'],
#       dtype='object')

# %%
df.shape
# Out:
# (999, 13)

# %%
df['Genetics'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Yes, No=df['Genetics'].value_counts()
print("Yes",Yes)
print('No',No)
# Out:
# Yes 522
# No 477

# %%
print('percentage of family yes baldness',Yes/len(df)*100,'%')
# Out:
# percentage of family baldness 52.25225225225225 %

# %%
print('percentage of family no baldness ',No/len(df)*100,'%')
# Out:
# percentage of family no baldness  47.74774774774775 %

# %%
df['Medical Conditions'].unique()
# Out:
# array(['No Data', 'Eczema', 'Dermatosis', 'Ringworm', 'Psoriasis',
#        'Alopecia Areata ', 'Scalp Infection', 'Seborrheic Dermatitis',
#        'Dermatitis', 'Thyroid Problems', 'Androgenetic Alopecia'],
#       dtype=object)

# %%
df['Medications & Treatments'].unique()
# Out:
# array(['No Data', 'Antibiotics', 'Antifungal Cream', 'Accutane',
#        'Chemotherapy', 'Steroids', 'Rogaine', 'Blood Pressure Medication',
#        'Immunomodulators', 'Antidepressants ', 'Heart Medication '],
#       dtype=object)

# %%
df['Nutritional Deficiencies '].unique()
# Out:
# array(['Magnesium deficiency', 'Protein deficiency', 'Biotin Deficiency ',
#        'Iron deficiency', 'Selenium deficiency', 'Omega-3 fatty acids',
#        'Zinc Deficiency', 'Vitamin A Deficiency', 'Vitamin D Deficiency',
#        'No Data', 'Vitamin E deficiency'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in df.columns:
    sns.scatterplot(data=df,x=col,y=df.index)

# %%
for col in df.columns:
    sns.barplot(data=df,x=col,y=df.index
               )

# %%
df.head()
# Out:
#        Id Genetics Hormonal Changes Medical Conditions  \
# 0  133992      Yes               No            No Data
# 1  148393       No               No             Eczema
# 2  155074       No               No         Dermatosis
# 3  118261      Yes              Yes           Ringworm
# 4  111915       No               No          Psoriasis
#
#   Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                  No Data      Magnesium deficiency  Moderate   19
# 1              Antibiotics      Magnesium deficiency      High   43
# 2         Antifungal Cream        Protein deficiency  Moderate   26
# 3              Antibiotics        Biotin Deficiency   Moderate   46
# 4                 Accutane           Iron deficiency  Moderate   30
#
#   Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   Hair Loss
# 0                    Yes                   Yes      No           No          0
# ...

# %%
medi_and_treat=df['Medications & Treatments'].value_counts()

# %%
fig,ax=plt.subplots()
plt.title('Medications & Treatments')
ax.pie(medi_and_treat,labels=df['Medications & Treatments'].unique(),autopct='%1.1f%%')
plt.legend('left')

# %%
medi_cond=df['Medical Conditions'].value_counts()
fig,ax=plt.subplots()
plt.title('Medical Conditions')
ax.pie(medi_cond,labels=df['Medical Conditions'].unique(),autopct='%1.1f%%')
plt.show()

# %%
df['Nutritional Deficiencies '].value_counts()
# Out:
# Nutritional Deficiencies
# Zinc Deficiency         108
# Vitamin D Deficiency    104
# Biotin Deficiency        99
# Vitamin A Deficiency     99
# Omega-3 fatty acids      92
# Protein deficiency       90
# Magnesium deficiency     84
# Vitamin E deficiency     83
# Selenium deficiency      82
# No Data                  80
# Iron deficiency          78
# Name: count, dtype: int64

# %%
Nutritional_def=df['Nutritional Deficiencies '].value_counts()
fig,ax=plt.subplots()
plt.title('Nutritional Deficiencies ')
ax.pie(Nutritional_def,labels=df['Nutritional Deficiencies '].unique(),autopct='%1.1f%%')
plt.show()

# %%
pert_cent=df['Stress'].value_counts()/len(df)*100

# %%
df['Stress'].value_counts()/len(df)*100
# Out:
# Stress
# Moderate    35.135135
# Low         32.732733
# High        32.132132
# Name: count, dtype: float64

# %%
fig,ax=plt.subplots()
plt.title('Stress')
ax.pie(pert_cent,labels=df['Stress'].unique(),autopct='%1.1f%%')
plt.show()

# %%
df['Poor Hair Care Habits '].value_counts()
# Out:
# Poor Hair Care Habits
# No     507
# Yes    492
# Name: count, dtype: int64

# %%
df['Environmental Factors'].value_counts()
# Out:
# Environmental Factors
# Yes    508
# No     491
# Name: count, dtype: int64

# %%
#Smoking	Weight Loss
print(f'smoking count of yes and no :',df['Smoking'].value_counts())



print(f'Weight count of yes and no :',df['Weight Loss '].value_counts())
# Out:
# smoking count of yes and no : Smoking
# Yes    519
# No     480
# Name: count, dtype: int64
# Weight count of yes and no : Weight Loss
# No     527
# Yes    472
# Name: count, dtype: int64

# %%
df=df.drop('Id',axis=1)

# %%
for i in df.columns:
    print(f"{i}: {data[i].unique()}\n{df[i].value_counts()}\n")
    print("="*50)
# Out:
# Genetics: ['Yes' 'No']
# Genetics
# Yes    522
# No     477
# Name: count, dtype: int64
#
# ...
# Hormonal Changes: ['No' 'Yes']
# Hormonal Changes
# Yes    509
# No     490
# Name: count, dtype: int64
#
# ...
# Medical Conditions: ['No Data' 'Eczema' 'Dermatosis' 'Ringworm' 'Psoriasis' 'Alopecia Areata '
#  'Scalp Infection' 'Seborrheic Dermatitis' 'Dermatitis' 'Thyroid Problems'
#  'Androgenetic Alopecia']
# Medical Conditions
# No Data                  110
# Alopecia Areata          107
# Psoriasis                100
# Thyroid Problems          99
# Androgenetic Alopecia     98
# Dermatitis                92
# Dermatosis                88
# Seborrheic Dermatitis     88
# Scalp Infection           79
# Eczema                    69
# Ringworm                  69
# Name: count, dtype: int64
#
# ...
# Medications & Treatments: ['No Data' 'Antibiotics' 'Antifungal Cream' 'Accutane' 'Chemotherapy'
#  'Steroids' 'Rogaine' 'Blood Pressure Medication' 'Immunomodulators'
# ...

# %%
df['Hair Loss']=df['Hair Loss'].map({0:'No',
                                    1:'Yes'})

# %%
df['Hair Loss']
# Out:
# 0       NO
# 1       NO
# 2       NO
# 3       NO
# 4      Yes
#       ...
# 994    Yes
# 995     NO
# 996    Yes
# 997    Yes
# 998    Yes
# Name: Hair Loss, Length: 999, dtype: object

# %%
numerical_cols=df.dtype_select(include !='object',inplace=True)
categorical_cols=df.dtype_select(exclude=='object',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\291166355.py in ?()
# ----> 1 numerical_cols=df.dtype_select(include !='object',inplace=True)
#       2 categorical_cols=df.dtype_select(exclude=='object',inplace=True)
#
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype_select'

# %%
df.head()
# Out:
#   Genetics Hormonal Changes Medical Conditions Medications & Treatments  \
# 0      Yes               No            No Data                  No Data
# 1       No               No             Eczema              Antibiotics
# 2       No               No         Dermatosis         Antifungal Cream
# 3      Yes              Yes           Ringworm              Antibiotics
# 4       No               No          Psoriasis                 Accutane
#
#   Nutritional Deficiencies     Stress  Age Poor Hair Care Habits   \
# 0      Magnesium deficiency  Moderate   19                    Yes
# 1      Magnesium deficiency      High   43                    Yes
# 2        Protein deficiency  Moderate   26                    Yes
# 3        Biotin Deficiency   Moderate   46                    Yes
# 4           Iron deficiency  Moderate   30                     No
#
#   Environmental Factors Smoking Weight Loss  Hair Loss
# 0                   Yes      No           No       NaN
# ...

# %%
X=df.drop('Hair Loss',axis=1)
y=df[['Hair Loss']]

# %%
X
# Out:
#          Id Genetics Hormonal Changes     Medical Conditions  \
# 0    133992      Yes               No                No Data
# 1    148393       No               No                 Eczema
# 2    155074       No               No             Dermatosis
# 3    118261      Yes              Yes               Ringworm
# 4    111915       No               No              Psoriasis
# ..      ...      ...              ...                    ...
# 994  184367      Yes               No  Seborrheic Dermatitis
# 995  164777      Yes              Yes                No Data
# 996  143273       No              Yes  Androgenetic Alopecia
# 997  169123       No              Yes             Dermatitis
# 998  127183      Yes              Yes              Psoriasis
#
#       Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                      No Data      Magnesium deficiency  Moderate   19
# 1                  Antibiotics      Magnesium deficiency      High   43
# ...

# %%
y
# Out:
#      Hair Loss
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ..         ...
# 994          1
# 995          0
# 996          1
# 997          1
# 998          1
#
# [999 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=42)

# %%
X_train
# Out:
#          Id Genetics Hormonal Changes     Medical Conditions  \
# 728  154142      Yes               No             Dermatitis
# 630  175025       No               No  Seborrheic Dermatitis
# 394  120849       No              Yes       Thyroid Problems
# 777  192622      Yes               No             Dermatitis
# 598  118226      Yes               No  Androgenetic Alopecia
# ..      ...      ...              ...                    ...
# 106  151443       No              Yes       Thyroid Problems
# 270  184325      Yes              Yes  Androgenetic Alopecia
# 860  151918      Yes               No  Seborrheic Dermatitis
# 435  189092      Yes              Yes       Alopecia Areata
# 102  179153      Yes               No              Psoriasis
#
#       Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 728                   Accutane           Zinc Deficiency       Low   29
# 630                    Rogaine                   No Data  Moderate   22
# ...

# %%
y_train
# Out:
#      Hair Loss
# 728          1
# 630          1
# 394          1
# 777          0
# 598          1
# ..         ...
# 106          0
# 270          0
# 860          0
# 435          1
# 102          1
#
# [699 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\1637727700.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler=StandardScaler()
# ----> 3 X_train=scaler.fit_transform(X_train)
#       4 X_test=scaler.transform(X_test)
#
# ~\miniconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     271     @wraps(f)
#     272     def wrapped(self, X, *args, **kwargs):
# --> 273         data_to_wrap = f(self, X, *args, **kwargs)
#     274         if isinstance(data_to_wrap, tuple):
#     275             # only wrap the first output for cross decomposition
#     276             return_tuple = (
#
# ~\miniconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1057                 )
#    1058
#    1059         if y is None:
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\2310286352.py in ?()
#       1 logreg=LogisticRegression()
# ----> 2 logreg.fit(X_train,y_train)
#
# ~\miniconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# ~\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1197             _dtype = np.float64
#    1198         else:
#    1199             _dtype = [np.float64, np.float32]
#    1200
# -> 1201         X, y = self._validate_data(
#    1202             X,
#    1203             y,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
ligreg=LinearRegression()
ligreg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\2766988986.py in ?()
#       1 ligreg=LinearRegression()
# ----> 2 ligreg.fit(X_train,y_train)
#
# ~\miniconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# ~\miniconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     574         n_jobs_ = self.n_jobs
#     575
#     576         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     577
# --> 578         X, y = self._validate_data(
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\3508300803.py in ?()
#       1 dtc=DecisionTreeClassifier()
# ----> 2 dtc.fit(X_train,y_train)
#
# ~\miniconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# ~\miniconda3\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
#    1007         """
#    1008
# -> 1009         super()._fit(
#    1010             X,
#    1011             y,
#    1012             sample_weight=sample_weight,
#
# ...

# %%
#knn=KNeighborsClassifier(n_neighbors=6
